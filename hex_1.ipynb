# %%
#Importing Required libraries
import numpy as np
import seaborn as sns
import pandas as pd

# %%
#inserting your dataset
data=pd.read_csv('marksheet.csv')

# %%
#displaying first few rows
data.head()
# Out:
#    id     Name  Gender  Age Section  Science  English  History  Maths
# 0   1  Bronnie  Female   13       C       21       81       62     49
# 1   2   Lemmie    Male   15       B       29       41       17     40
# 2   3    Danya  Female   14       C       12       87       16     96
# 3   4    Denna  Female   14       B       15       53       82     33
# 4   5  Jocelin    Male   14       A       43        6        3     21

# %%
#checking the total no.of rows and columns
data.shape
# Out:
# (250, 9)

# %%
data.describe()
# Out:
#                id         Age     Science     English     History       Maths
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean   125.500000   14.020000   51.440000   47.980000   52.272000   53.016000
# std     72.312977    0.823598   29.314497   29.949013   26.868526   27.386416
# min      1.000000   13.000000    1.000000    1.000000    1.000000    1.000000
# 25%     63.250000   13.000000   25.250000   20.250000   31.000000   30.000000
# 50%    125.500000   14.000000   53.000000   47.500000   53.000000   52.500000
# 75%    187.750000   15.000000   78.000000   74.000000   76.000000   76.000000
# max    250.000000   15.000000  100.000000  100.000000  100.000000  100.000000

# %%
data.columns
# Out:
# Index(['id', 'Name', 'Gender', 'Age', 'Section', 'Science', 'English',
#        'History', 'Maths'],
#       dtype='object')

# %%
#shows no.of unique elements present
data.nunique()
# Out:
# id         250
# Name       247
# Gender       2
# Age          3
# Section      3
# Science     91
# English     93
# History     91
# Maths       93
# dtype: int64

# %%
#checking if there is any null values
data.isnull().sum()
# Out:
# id         0
# Name       0
# Gender     0
# Age        0
# Section    0
# Science    0
# English    0
# History    0
# Maths      0
# dtype: int64

# %%
data.columns
# Out:
# Index(['id', 'Name', 'Gender', 'Age', 'Section', 'Science', 'English',
#        'History', 'Maths'],
#       dtype='object')

# %%
#droping the columns
student= data.drop(['Section','Name'],axis=1)

# %%
#displays dataset either float or integer
student=data.select_dtypes(include=['float','int64'])

# %%
sns.heatmap(student.corr(),annot=True,cmap='coolwarm',linewidths=0.5)
# Out:
# <Axes: >

# %%
sns.pairplot(student)
# Out:
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='Science',y='Maths',hue='Age',data=student)
# Out:
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(student['Science'])
# Out:
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='Maths',kind='box',data=student)
# Out:
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
